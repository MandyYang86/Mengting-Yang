# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
import random
import os
import glob

# %matplotlib inline
# Make plots larger
plt.rcParams['figure.figsize'] = (15, 9)

# %%
uber_ds = pd.read_csv("uber.csv")
lyft_ds =pd.read_csv('lyft.csv')
#Save Orignal Data
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (0,1,6,7,12,18,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
uber_ds.columns
# Out:
# Index(['currency_code', 'date', 'day', 'display_name', 'distance', 'duration',
#        'end_latitude', 'end_location', 'end_longitude', 'estimate',
#        'high_estimate', 'localized_display_name', 'low_estimate', 'main_temp',
#        'main_temp_max', 'main_temp_min', 'product_id', 'start_latitude',
#        'start_location', 'start_longitude', 'time', 'weather'],
#       dtype='object')

# %%
lyft_ds.columns
# Out:
# Index(['can_request_ride', 'cost_token', 'lyft_currency', 'date', 'day',
#        'display_name', 'end_latitude', 'end_longitude',
#        'lyft_estimated_cost_cents_max', 'lyft_estimated_cost_cents_min',
#        'lyft_estimated_distance_miles', 'lyft_estimated_duration_seconds',
#        'lyft_is_valid_estimate', 'lyft_primetime_percentage', 'lyft_ride_type',
#        'start_latitude', 'start_longitude', 'time', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21',
#        'lyft_localized_display_name'],
#       dtype='object')

# %%
uber_ds.rename(columns={'currency_code': 'uber_currency_code', 'distance': 'uber_distance',
                        'duration': 'uber_duration','end_location': 'uber_end_location','estimate': 'uber_estimate',
                        'high_estimate': 'uber_high_estimate', 'localized_display_name': 'uber_localized_display_name',
                        'low_estimate': 'uber_low_estimate','main_temp': 'uber_main_temp',
                        'product_id': 'uber_product_id',
                        'start_location': 'uber_start_location', 'weather': 'uber_weather'}, inplace=True)

# %%
lyft_ds.rename(columns={'currency': 'lyft_currency',
       'estimated_cost_cents_max': 'lyft_estimated_cost_cents_max', 'estimated_cost_cents_min': 'lyft_estimated_cost_cents_min',
       'estimated_distance_miles': 'lyft_estimated_distance_miles', 'estimated_duration_seconds': 'lyft_estimated_duration_seconds',
       'is_valid_estimate': 'lyft_is_valid_estimate', 'primetime_percentage': 'lyft_primetime_percentage', 'ride_type': 'lyft_ride_type'
       }, inplace=True)

# %%
lyft_ds['lyft_localized_display_name'] = lyft_ds['display_name']

# %%
lyft_ds.drop(['can_request_ride', 'cost_token', 'lyft_currency', 'lyft_is_valid_estimate',
              'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20'], axis=1, inplace=True)

# %%
uber_ds.drop(['uber_currency_code', 'uber_estimate','uber_product_id','main_temp_max','main_temp_min'], axis=1, inplace=True)

# %%
uber_ds = uber_ds[uber_ds.display_name != 'TAXI']

# %%
lyft_ds['display_name'].unique()
# Out:
# array(['Lyft Premier', 'Lyft Line', 'Lyft Lux', 'Lyft', 'Lyft Plus',
#        'Lyft Lux SUV', 'March 01, 2018'], dtype=object)

# %%
lyft_ds = lyft_ds[lyft_ds.display_name != 'March 01, 2018']

# %%
lyft_ds['display_name'].unique()
# Out:
# array(['Lyft Premier', 'Lyft Line', 'Lyft Lux', 'Lyft', 'Lyft Plus',
#        'Lyft Lux SUV'], dtype=object)

# %%
lyft_ds['display_name'] = lyft_ds['display_name'].map({'Lyft': 'non_sharing_standard', 'Lyft Line': 'sharing_standard', 'Lyft Premier': 'luxury_sedan', 'Lyft Lux' : 'luxary', 'Lyft Plus' : 'extra_seats', 'Lyft Lux SUV' : 'black_lux' })
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
uber_ds['display_name'].unique()
# Out:
# array(['POOL', 'uberX', 'uberSUV', 'uberXL', 'UberBLACK', 'uberWAV'], dtype=object)

# %%
uber_ds['display_name'] = uber_ds['display_name'].map({'uberX': 'non_sharing_standard', 'POOL': 'sharing_standard', 'uberWAV': 'luxury_sedan', 'uberSUV' : 'luxary', 'uberXL' : 'extra_seats', 'UberBLACK' : 'black_lux' })

# %%
uber_ds['date_time'] = uber_ds['date'].astype(str) + ' ' + uber_ds['time']

# %%
uber_ds['date_time'] = pd.to_datetime(uber_ds['date_time'])

# %%
uber_ds['date_time'] = uber_ds['date_time'].dt.round('T')

# %%
uber_ds['key'] = uber_ds['date_time'].astype(str)+ ' ' + uber_ds['display_name']

# %%
lyft_ds['date_time'] = lyft_ds['date'].astype(str) + ' ' + lyft_ds['time']
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lyft_ds['date_time'] = pd.to_datetime(lyft_ds['date_time'])
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lyft_ds['date_time'] = lyft_ds['date_time'].dt.round('T')
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
lyft_ds['key'] = lyft_ds['date_time'].astype(str)+ ' ' + lyft_ds['display_name']
# Out:
# C:\Users\Rahil\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
uber_ds.to_csv('out1.csv', sep=',')

# %%
uber_copy = uber_ds

# %%
uber_copy.merge(lyft_ds, on=['date_time','display_name'])
# Out:
#                   date_x   day_x          display_name  uber_distance  \
# 0      February 23, 2018  Friday      sharing_standard           1.69
# 1      February 23, 2018  Friday  non_sharing_standard           1.69
# 2      February 23, 2018  Friday                luxary           1.69
# 3      February 23, 2018  Friday           extra_seats           1.69
# 4      February 23, 2018  Friday             black_lux           1.69
# 5      February 23, 2018  Friday          luxury_sedan           1.69
# 6      February 23, 2018  Friday      sharing_standard           2.20
# 7      February 23, 2018  Friday  non_sharing_standard           2.20
# 8      February 23, 2018  Friday                luxary           2.20
# 9      February 23, 2018  Friday           extra_seats           2.20
# 10     February 23, 2018  Friday             black_lux           2.20
# 11     February 23, 2018  Friday          luxury_sedan           2.20
# ...

# %%
uber_copy.to_csv('Mergedout.csv')
